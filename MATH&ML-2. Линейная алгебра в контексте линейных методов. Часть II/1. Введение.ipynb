# %% [markdown]
# Так как скалярное произведение векторов  и  равно 0, то векторы ортогональны друг другу и являются линейно независимыми.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Как следует из предыдущего задания, ранг системы равен 2, что меньше количества векторов в системе, а значит вектора являются линейно зависимыми.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
