# %% [markdown]
# [link](https://apps.skillfactory.ru/learning/course/course-v1:SkillFactory+DST-3.0+28FEB2021/block-v1:SkillFactory+DST-3.0+28FEB2021+type@sequential+block@548c7778fc5f4fde88d685d5f0497973/block-v1:SkillFactory+DST-3.0+28FEB2021+type@vertical+block@60cdea7369d342d6ab754d28840aef25)

# %% [markdown]
# Умножение матриц:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %%
import numpy as np

A = np.matrix("1, -5; 2, 2; 0, 3")
B = np.matrix("3, 1, 0; -1, 0, 2")

display(np.dot(A, B))

display(np.dot(B, A))
# Out:
# matrix([[  8,   1, -10],
#         [  4,   2,   4],
#         [ -3,   0,   6]])
# matrix([[  5, -13],
#         [ -1,  11]])

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Умножение матрицы на вектор
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Правило. Вектор-столбец умножается на матрицу справа, а вектор-строка — слева.
#
# По определению произведения матриц результатом умножения матрицы на вектор всегда получается вектор той же размерности, что и исходный.

# %% [markdown]
# Тензорное умножение векторов:
#
# Тензорное произведение — это результат матричного умножения вектора-столбца на вектор-строку. Результатом тензорного произведения является матрица.
#
# ![image.png](attachment:image.png)
#
# Сравним со сколярным произведением веторов:
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# УМНОЖЕНИЕ НА СПЕЦИАЛЬНЫЕ МАТРИЦЫ

# %% [markdown]
# УМНОЖЕНИЕ НА НУЛЕВУЮ МАТРИЦУ
# ![image.png](attachment:image.png)

# %% [markdown]
# УМНОЖЕНИЕ НА ЕДИНИЧНУЮ МАТРИЦУ
#
# ![image.png](attachment:image.png)

# %% [markdown]
# УМНОЖЕНИЕ НА ШАРОВУЮ МАТРИЦУ
#
# ![image.png](attachment:image.png)

# %% [markdown]
# УМНОЖЕНИЕ НА ДИАГОНАЛЬНУЮ МАТРИЦУ
#
# ![image.png](attachment:image.png)

# %% [markdown]
# * При умножении на диагональную матрицу справа каждый столбец матрицы  умножается на соответствующий коэффициент, стоящий на диагонали матрицы .
# * При умножении на диагональную матрицу слева каждая строка матрицы  умножается на соответствующий коэффициент, стоящий на диагонали матрицы .
# * Умножение на диагональную матрицу не является перестановочным в общем случае.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Важные выводы:
#
# * Нулевая и единичная матрицы играют роль нуля и единицы в матричном умножении.
# * Умножение на шаровую матрицу — то же самое, что умножение на скаляр.
# * Умножение на диагональную матрицу даёт растяжение каждого столбца или строки.
# * Диагональные матрицы коммутативны между собой.

# %% [markdown]
# УМНОЖЕНИЕ И ТРАНСПОНИРОВАНИЕ МАТРИЦ

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
