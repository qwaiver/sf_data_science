# %% [markdown]
# [link](https://apps.skillfactory.ru/learning/course/course-v1:SkillFactory+DST-3.0+28FEB2021/block-v1:SkillFactory+DST-3.0+28FEB2021+type@sequential+block@548c7778fc5f4fde88d685d5f0497973/block-v1:SkillFactory+DST-3.0+28FEB2021+type@vertical+block@993d362dd8fc4fc8ae0a2058d704957a)

# %%
import numpy as np

t = np.array([12, 14, 17, 19, 24, 28, 31, 31, 27, 22, 17, 13])

# %%
t.mean()
# Out:
# 21.25

# %% [markdown]
# Сложение и вычитание векторов в Python происходит при помощи знаков + и -. Причём важно задать векторы именно как массивы numpy, а не как обычные списки типа list.

# %%
a = np.array([10, 8, 5, 1])
b = np.array([5, 15, 9, 7])
a + b
## array([15, 23, 14,  8])
a - b
## array([ 5, -7, -4, -6])
# Out:
# array([ 5, -7, -4, -6])

# %% [markdown]
# В Python число умножается на массив numpy обычным оператором умножения.

# %%
a = np.array([120, 45, 68])
omega = 0.2
c = a * omega
c
## array([24. ,  9. , 13.6])
# Out:
# array([24. ,  9. , 13.6])

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2.5 Ниже представлены доходы семьи за три месяца.
#
# Доходы мужа: 120, 150 и 190 тысяч рублей.
#
# Доходы жены: 130, 130 и 130 тысяч рублей.
#
# Доходы тёщи: 2, 3 и 2.5 тысячи евро.
#
# Вводите координаты полученных векторов через запятую (без пробела). Пример ввода ответа: 0,1,1.
#
# Найдите вектор доходов тёщи в тыс. рублей, если курс евро составляет 72 рубля.
#   нет ответа
# Найдите вектор суммарного дохода семьи в тыс. рублей по месяцам.

# %%
m = np.array([120, 150, 190])
w = np.array([130, 130, 130])
t = np.array([2, 3, 2.5])

# %%
tr = t*72
tr
# Out:
# array([144., 216., 180.])

# %%
m+w+tr
# Out:
# array([394., 496., 500.])

# %% [markdown]
# В Python линейная комбинация полностью соответствует своему названию и вычисляется как комбинация сложения векторов и умножения вектора на число.

# %%
p = np.array([2, 4, 5])
v = np.array([8, 10, 2])
s = np.array([0, 12, 7])
omega1 = 500
omega2 = 100
omega3 = 0
u = omega1*p + omega2*v + omega3*s
u
## array([1800, 3000, 2700])
# Out:
# array([1800, 3000, 2700])

# %%
#2.8

a = np.array([3,4,5,9])

b = np.array([1,5,3,6])

s = 400*b-200*a
display(s)
# Out:
# array([-200, 1200,  200,  600])

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Существует четыре способа умножить векторы между собой:
#
# * Скалярное произведение. Результат — число.
# * Векторное произведение. Результат — вектор.
# * Смешанное произведение. Результат — число.
# * Тензорное произведение. Результат — матрица.

# %% [markdown]
# СКАЛЯРНОЕ ПРОИЗВЕДЕНИЕ ВЕКТОРОВ

# %% [markdown]
# В Python скалярное произведение векторов вычисляется при помощи функции np.dot():

# %%
a = np.array([65, 70, 120, 30])
w = np.array([0.4, 0.4, 0.2, 0.8])
np.dot(a, w) #сумма значений при a*w
## 102.0
# Out:
# 102.0

# %% [markdown]
# Таким образом, в линейной алгебре длина вектора определяется как квадратный корень из скалярного произведения вектора с самим собой.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#2.11 найти скалярное произведение векторов
a = np.array([4, 5, -1])
w = np.array([2, 0, 1])
np.dot(a, w) #сумма значений при a*w
# Out:
# 7

# %% [markdown]
# ![image.png](attachment:image.png)
